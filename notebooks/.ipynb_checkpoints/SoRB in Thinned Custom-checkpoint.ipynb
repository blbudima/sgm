# %% [markdown]
# # Import dependencies

# %%
# Reload modules whenever underlying code changes
# %load_ext autoreload
# %autoreload 2

# %%
# pdb will automatically run on exceptions
#%pdb on # currently not working due to https://github.com/ipython/ipykernel/issues/422

# %%
# import os

# # Only occupy one GPU, as in https://stackoverflow.com/questions/37893755/tensorflow-set-cuda-visible-devices-within-jupyter
# os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"   # see issue #152
# os.environ["CUDA_VISIBLE_DEVICES"]="0"

# # Only allocate GPU memory as needed
# os.environ["TF_FORCE_GPU_ALLOW_GROWTH"]="true"

# # Suppress tf warning messages
# os.environ["TF_CPP_MIN_LOG_LEVEL"]="3"

# %%
# %matplotlib inline
from sgm.dependencies import *

# %% [markdown]
# # Initialize untrained agent

# %%
# config = tf.ConfigProto()
# config.gpu_options.allow_growth = True
# tf.enable_eager_execution(config=config)

# %%
#tf.debugging.set_log_device_placement(True)
tf.test.is_gpu_available()
# Out:
# True

# %%
tf.reset_default_graph()

# %%
from sgm.envs import env_load_fn
from sgm.agent import UvfAgent

# If you change the environment parameters below, make sure to run
# tf.reset_default_graph() in the cell above before training.
max_episode_steps = 18
env_name = 'Custom'  # Choose one of the environments shown above. 
resize_factor = 5  # Inflate the environment to increase the difficulty.
thin = True # If True, resize by expanding open space, not walls, to make walls thin
desc_name = "thinned_" + env_name.lower() if thin else env_name.lower()

base_dir = os.path.join(os.getcwd(), os.pardir, "agents")
model_dir = os.path.join(base_dir, desc_name)

tf_env = env_load_fn(env_name, max_episode_steps,
                     resize_factor=resize_factor,
                     terminate_on_timeout=False,
                     thin=thin)
eval_tf_env = env_load_fn(env_name, max_episode_steps,
                          resize_factor=resize_factor,
                          terminate_on_timeout=True,
                          thin=thin)

agent = UvfAgent(
    tf_env.time_step_spec(),
    tf_env.action_spec(),
    max_episode_steps=max_episode_steps,
    use_distributional_rl=True,
    ensemble_size=3)
# Out:
# /home/blbudima/miniconda3/envs/sgm/lib/python3.6/site-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# WARNING:tensorflow:From /home/blbudima/miniconda3/envs/sgm/lib/python3.6/site-packages/tf_agents/agents/ddpg/actor_network.py:101: The name tf.keras.initializers.RandomUniform is deprecated. Please use tf.compat.v1.keras.initializers.RandomUniform instead.

# %% [markdown]
# # Train the agent

# %%
from sgm.trainer import train_eval

train_eval(agent,
          tf_env,
          eval_tf_env,
          initial_collect_steps=1000,
          eval_interval=1000,
          num_eval_episodes=10,
          num_iterations=30000,
          save_model_dir=model_dir,
          experiment_name=f"{env_name}_coordinate_{max_episode_steps}steps")
# Out:
# INFO:tensorflow:random_seed = 0
# WARNING:tensorflow:From /home/blbudima/miniconda3/envs/sgm/lib/python3.6/site-packages/tensorflow_core/python/ops/resource_variable_ops.py:1781: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From /home/blbudima/miniconda3/envs/sgm/lib/python3.6/site-packages/tf_agents/replay_buffers/tf_uniform_replay_buffer.py:545: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# INFO:tensorflow:Saving checkpoints to directory /home/blbudima/sgm/notebooks/../agents/thinned_fourrooms/FourRooms_coordinate_20steps-May-09-2021-02-08-19-PM/ckpt
# INFO:tensorflow:Creating tensorboard summary writer with directory /home/blbudima/sgm/notebooks/../agents/thinned_fourrooms/FourRooms_coordinate_20steps-May-09-2021-02-08-19-PM
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#   3%|▎         | 991/30000 [00:14<05:34, 86.60it/s]
# Saved checkpoint for step 1000: /home/blbudima/sgm/notebooks/../agents/thinned_fourrooms/FourRooms_coordinate_20steps-May-09-2021-02-08-19-PM/ckpt/ckpt-1
# INFO:tensorflow:step = 1000, loss = 2.208775
# INFO:tensorflow:74.875 steps/sec
# INFO:tensorflow:step = 1000
# INFO:tensorflow:	 set goal dist = 2
# INFO:tensorflow:		 AverageReturn (eval distance=2.000000) -20.00
# INFO:tensorflow:		 predicted_dist = 14.8 (0.5)
# INFO:tensorflow:	 set goal dist = 5
# INFO:tensorflow:		 AverageReturn (eval distance=5.000000) -20.00
# INFO:tensorflow:		 predicted_dist = 14.8 (0.9)
# INFO:tensorflow:	 set goal dist = 10
# INFO:tensorflow:		 AverageReturn (eval distance=10.000000) -20.00
# INFO:tensorflow:		 predicted_dist = 15.1 (0.8)
# INFO:tensorflow:	 eval_time = 4.08
#   7%|▋         | 1997/30000 [00:30<04:54, 95.21it/s]
# Saved checkpoint for step 2000: /home/blbudima/sgm/notebooks/../agents/thinned_fourrooms/FourRooms_coordinate_20steps-May-09-2021-02-08-19-PM/ckpt/ckpt-2
# INFO:tensorflow:step = 2000, loss = 1.835765
# INFO:tensorflow:100.627 steps/sec
# INFO:tensorflow:step = 2000
# INFO:tensorflow:	 set goal dist = 2
# INFO:tensorflow:		 AverageReturn (eval distance=2.000000) -18.50
# INFO:tensorflow:		 predicted_dist = 14.6 (1.6)
# INFO:tensorflow:	 set goal dist = 5
# INFO:tensorflow:		 AverageReturn (eval distance=5.000000) -20.00
# INFO:tensorflow:		 predicted_dist = 16.2 (0.6)
# INFO:tensorflow:	 set goal dist = 10
# INFO:tensorflow:		 AverageReturn (eval distance=10.000000) -19.20
# INFO:tensorflow:		 predicted_dist = 16.7 (0.5)
# INFO:tensorflow:	 eval_time = 3.51
#  10%|▉         | 2997/30000 [00:44<04:47, 94.01it/s]
# Saved checkpoint for step 3000: /home/blbudima/sgm/notebooks/../agents/thinned_fourrooms/FourRooms_coordinate_20steps-May-09-2021-02-08-19-PM/ckpt/ckpt-3
# INFO:tensorflow:step = 3000, loss = 1.333094
# INFO:tensorflow:100.593 steps/sec
# INFO:tensorflow:step = 3000
# INFO:tensorflow:	 set goal dist = 2
# INFO:tensorflow:		 AverageReturn (eval distance=2.000000) -18.00
# INFO:tensorflow:		 predicted_dist = 15.4 (1.6)
# INFO:tensorflow:	 set goal dist = 5
# INFO:tensorflow:		 AverageReturn (eval distance=5.000000) -16.90
# INFO:tensorflow:		 predicted_dist = 16.0 (1.5)
# INFO:tensorflow:	 set goal dist = 10
# INFO:tensorflow:		 AverageReturn (eval distance=10.000000) -20.00
# INFO:tensorflow:		 predicted_dist = 17.6 (0.7)
# INFO:tensorflow:	 eval_time = 3.08
#  13%|█▎        | 3998/30000 [00:58<04:48, 90.27it/s]
# Saved checkpoint for step 4000: /home/blbudima/sgm/notebooks/../agents/thinned_fourrooms/FourRooms_coordinate_20steps-May-09-2021-02-08-19-PM/ckpt/ckpt-4
# INFO:tensorflow:step = 4000, loss = 1.398484
# INFO:tensorflow:107.177 steps/sec
# INFO:tensorflow:step = 4000
# INFO:tensorflow:	 set goal dist = 2
# INFO:tensorflow:		 AverageReturn (eval distance=2.000000) -13.30
# INFO:tensorflow:		 predicted_dist = 15.1 (1.8)
# INFO:tensorflow:	 set goal dist = 5
# INFO:tensorflow:		 AverageReturn (eval distance=5.000000) -19.20
# INFO:tensorflow:		 predicted_dist = 17.7 (0.8)
# INFO:tensorflow:	 set goal dist = 10
# INFO:tensorflow:		 AverageReturn (eval distance=10.000000) -20.00
# INFO:tensorflow:		 predicted_dist = 18.4 (0.3)
# INFO:tensorflow:	 eval_time = 2.68
#  17%|█▋        | 4995/30000 [01:12<04:51, 85.86it/s]
# Saved checkpoint for step 5000: /home/blbudima/sgm/notebooks/../agents/thinned_fourrooms/FourRooms_coordinate_20steps-May-09-2021-02-08-19-PM/ckpt/ckpt-5
# INFO:tensorflow:step = 5000, loss = 1.127369
# INFO:tensorflow:106.120 steps/sec
# INFO:tensorflow:step = 5000
# INFO:tensorflow:	 set goal dist = 2
# INFO:tensorflow:		 AverageReturn (eval distance=2.000000) -16.70
# INFO:tensorflow:		 predicted_dist = 15.6 (1.5)
# INFO:tensorflow:	 set goal dist = 5
# INFO:tensorflow:		 AverageReturn (eval distance=5.000000) -19.80
# INFO:tensorflow:		 predicted_dist = 17.7 (1.0)
# INFO:tensorflow:	 set goal dist = 10
# INFO:tensorflow:		 AverageReturn (eval distance=10.000000) -19.00
# INFO:tensorflow:		 predicted_dist = 18.6 (0.2)
# INFO:tensorflow:	 eval_time = 2.98
#  20%|█▉        | 5994/30000 [01:25<04:06, 97.24it/s]
# Saved checkpoint for step 6000: /home/blbudima/sgm/notebooks/../agents/thinned_fourrooms/FourRooms_coordinate_20steps-May-09-2021-02-08-19-PM/ckpt/ckpt-6
# INFO:tensorflow:step = 6000, loss = 1.072846
# INFO:tensorflow:106.652 steps/sec
# INFO:tensorflow:step = 6000
# INFO:tensorflow:	 set goal dist = 2
# INFO:tensorflow:		 AverageReturn (eval distance=2.000000) -15.40
# INFO:tensorflow:		 predicted_dist = 15.1 (2.2)
# INFO:tensorflow:	 set goal dist = 5
# INFO:tensorflow:		 AverageReturn (eval distance=5.000000) -18.80
# INFO:tensorflow:		 predicted_dist = 17.1 (1.1)
# INFO:tensorflow:	 set goal dist = 10
# INFO:tensorflow:		 AverageReturn (eval distance=10.000000) -20.00
# INFO:tensorflow:		 predicted_dist = 17.9 (0.5)
# INFO:tensorflow:	 eval_time = 2.95
#  23%|██▎       | 6990/30000 [01:39<03:53, 98.73it/s]
# Saved checkpoint for step 7000: /home/blbudima/sgm/notebooks/../agents/thinned_fourrooms/FourRooms_coordinate_20steps-May-09-2021-02-08-19-PM/ckpt/ckpt
ourRooms_coordinate_20steps-May-09-2021-02-08-19-PM/ckpt/ckpt-30
# INFO:tensorflow:step = 30000, loss = 3.125830
# INFO:tensorflow:112.929 steps/sec
# INFO:tensorflow:step = 30000
# INFO:tensorflow:	 set goal dist = 2
# INFO:tensorflow:		 AverageReturn (eval distance=2.000000) -4.40
# INFO:tensorflow:		 predicted_dist = 6.3 (1.1)
# INFO:tensorflow:	 set goal dist = 5
# INFO:tensorflow:		 AverageReturn (eval distance=5.000000) -8.90
# INFO:tensorflow:		 predicted_dist = 9.1 (1.7)
# INFO:tensorflow:	 set goal dist = 10
# INFO:tensorflow:		 AverageReturn (eval distance=10.000000) -16.70
# INFO:tensorflow:		 predicted_dist = 12.5 (1.1)
# INFO:tensorflow:	 eval_time = 2.41
# 100%|██████████| 30000/30000 [06:37<00:00, 75.48it/s]
# LossInfo(loss=<tf.Tensor: id=1149426, shape=(), dtype=float32, numpy=3.1258304>, extra=(<tf.Tensor: id=1149427, shape=(), dtype=float32, numpy=0.84553295>, <tf.Tensor: id=1149428, shape=(), dtype=float32, numpy=2.2802975>))

# %% [markdown]
# # Load trained model into agent

# %%
filename = "FourRooms_coordinate_20steps-May-09-2021-02-08-19-PM/ckpt/"
checkpoint_file = os.path.join(model_dir, filename)

ckpt = tf.train.Checkpoint(step=tf.Variable(1), net=agent)
manager = tf.train.CheckpointManager(ckpt, checkpoint_file, max_to_keep=3)
ckpt.restore(manager.latest_checkpoint)

# %% [markdown]
# # Fill replay buffer with random prefectly explored data

# %%
from sgm.envs import *

#@title Fill the replay buffer with random data  {vertical-output: true, run: "auto" }
replay_buffer_size = 2000 #@param {min:100, max: 1000, step: 100, type:"slider"}

eval_tf_env.pyenv.envs[0].gym.set_sample_goal_args(
    prob_constraint=0.0,
    min_dist=0,
    max_dist=6)
rb_vec = []
for it in range(replay_buffer_size):
    ts = eval_tf_env.reset()
    rb_vec.append(ts.observation['observation'].numpy()[0])
rb_vec = np.array(rb_vec)

# %%
plt.figure(figsize=(6, 6))
plt.scatter(*rb_vec.T)
plot_walls(eval_tf_env.pyenv.envs[0].env.walls)
plt.show()

# %% [markdown]
# # Calculate qvalue distances

# %%
pdist = agent._get_pairwise_dist(rb_vec, aggregate=None).numpy()

# %%
plt.figure(figsize=(6, 3))
plt.hist(pdist.flatten(), bins=range(20))
plt.xlabel('predicted distance')
plt.ylabel('number of (s, g) pairs')
plt.show()

# %% [markdown]
# # Calculate Euclidean distances

# %%
from scipy.spatial import distance
euclidean_dists = distance.pdist(rb_vec)

plt.figure(figsize=(6, 3))
plt.hist(euclidean_dists.flatten())
plt.xlabel('Euclidean distance')
plt.ylabel('number of pairwise distances')
plt.show()

# %% [markdown]
# # Initialize SoRB search policy

# %%
from sgm.planner import SoRBSearchPolicy
search_policy_type = "SoRB"
agent.initialize_search(rb_vec, max_search_steps=18)
search_policy = SoRBSearchPolicy(agent, pdist, rb_vec)

# %% [markdown]
# # Cleanup and evaluate SoRB

# %%
from sgm.evaluation import cleanup_and_eval

logdir = os.path.join(os.getcwd(), os.pardir, "logs")
eval_difficulty = 0.95
k_nearest = 5
eval_trials = 20
total_cleanup_steps = 1000
eval_period = 1000

logfolder = cleanup_and_eval(search_policy,
                             search_policy_type,
                             desc_name,
                             eval_tf_env,
                             logdir,
                             eval_difficulty=eval_difficulty,
                             k_nearest=k_nearest,
                             eval_trials=eval_trials,
                             total_cleanup_steps=total_cleanup_steps,
                             eval_period=eval_period)
# Out:
# SoRB has initial success rate 0.00
# Evaluated initial SoRB success rate in 848.76 seconds
# After filtering and 0 cleanup steps, SoRB has success rate 0.15
# Took 5000 cleanup steps and evaluated SoRB success rate in 6529.94 seconds
# After filtering and 5000 cleanup steps, SoRB has success rate 0.50
# Took 5000 cleanup steps and evaluated SoRB success rate in 3909.58 seconds
# After filtering and 10000 cleanup steps, SoRB has success rate 0.35
# Took 5000 cleanup steps and evaluated SoRB success rate in 4068.21 seconds
# After filtering and 15000 cleanup steps, SoRB has success rate 0.30
# Took 5000 cleanup steps and evaluated SoRB success rate in 4167.24 seconds
# After filtering and 20000 cleanup steps, SoRB has success rate 0.35
# Took 5000 cleanup steps and evaluated SoRB success rate in 3751.24 seconds
# After filtering and 25000 cleanup steps, SoRB has success rate 0.25
# Took 5000 cleanup steps and evaluated SoRB success rate in 3099.87 seconds
# After filtering and 30000 cleanup steps, SoRB has success rate 0.25
# Took 5000 cleanup steps and evaluated SoRB success rate in 4305.01 seconds
# After filtering and 35000 cleanup steps, SoRB has success rate 0.35
# Took 5000 cleanup steps and evaluated SoRB success rate in 3613.96 seconds
# After filtering and 40000 cleanup steps, SoRB has success rate 0.35
# Took 5000 cleanup steps and evaluated SoRB success rate in 3781.69 seconds
# After filtering and 45000 cleanup steps, SoRB has success rate 0.55
# Took 5000 cleanup steps and evaluated SoRB success rate in 3470.51 seconds
# After filtering and 50000 cleanup steps, SoRB has success rate 0.35

# %% [markdown]
# # Load cleanup graphs

# %%
from sgm.utils.visualization import *

search_policy.load(os.path.join(logfolder, search_policy_type.lower().replace(" ", "_") + "_initial"))
initial_graph = search_policy._g.copy()

search_policy.load(os.path.join(logfolder, search_policy_type.lower().replace(" ", "_") + "_filtered_0_cleanup_steps/"))
filtered_graph = search_policy._g.copy()

search_policy.load(os.path.join(logfolder, search_policy_type.lower().replace(" ", "_") + "_filtered_{}_cleanup_steps/".format(total_cleanup_steps)))
cleaned_graph = search_policy._g.copy()

pruned_graph = nx.difference(filtered_graph, cleaned_graph)

# %% [markdown]
# # Visualize cleanup graphs

# %%
plot_points(search_policy.rb_vec, eval_tf_env)

# %%
plot_graph(initial_graph, search_policy.rb_vec, eval_tf_env)
# Out:
# Plotting 1995 nodes and 30266 edges

# %%
plot_graph(filtered_graph, search_policy.rb_vec, eval_tf_env)
# Out:
# Plotting 1995 nodes and 9854 edges

# %%
plot_graph(cleaned_graph, search_policy.rb_vec, eval_tf_env)
# Out:
# Plotting 1995 nodes and 9689 edges

# %%
plot_graph(pruned_graph, search_policy.rb_vec, eval_tf_env)
# Out:
# Plotting 1995 nodes and 165 edges
