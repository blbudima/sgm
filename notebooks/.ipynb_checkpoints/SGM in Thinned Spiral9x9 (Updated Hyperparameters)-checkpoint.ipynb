# %% [markdown]
# # Import dependencies

# %%
# Reload modules whenever underlying code changes
# %load_ext autoreload
# %autoreload 2

# %%
# pdb will automatically run on exceptions
#%pdb on # currently not working due to https://github.com/ipython/ipykernel/issues/422

# %%
# import os

# # Only occupy one GPU, as in https://stackoverflow.com/questions/37893755/tensorflow-set-cuda-visible-devices-within-jupyter
# os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"   # see issue #152
# os.environ["CUDA_VISIBLE_DEVICES"]="0"

# # Only allocate GPU memory as needed
# os.environ["TF_FORCE_GPU_ALLOW_GROWTH"]="true"

# # Suppress tf warning messages
# os.environ["TF_CPP_MIN_LOG_LEVEL"]="3"

# %%
# %matplotlib inline
from sgm.dependencies import *

# %% [markdown]
# # Initialize untrained agent

# %%
# config = tf.ConfigProto()
# config.gpu_options.allow_growth = True
# tf.enable_eager_execution(config=config)

# %%
# tf.debugging.set_log_device_placement(True)
tf.test.is_gpu_available()
# Out:
# True

# %%
# from tensorflow.python.client import device_lib
# print(device_lib.list_local_devices())

# %%
tf.reset_default_graph()

# %%
from sgm.envs import env_load_fn
from sgm.agent import UvfAgent

# If you change the environment parameters below, make sure to run
# tf.reset_default_graph() in the cell above before training.
max_episode_steps = 30
env_name = 'Spiral9x9'  # Choose one of the environments shown above. 
resize_factor = 5  # Inflate the environment to increase the difficulty.
thin = True # If True, resize by expanding open space, not walls, to make walls thin
desc_name = "thinned_" + env_name.lower() if thin else env_name.lower()

base_dir = os.path.join(os.getcwd(), os.pardir, "agents")
model_dir = os.path.join(base_dir, desc_name)

tf_env = env_load_fn(env_name, max_episode_steps,
                     resize_factor=resize_factor,
                     terminate_on_timeout=False,
                     thin=thin)
eval_tf_env = env_load_fn(env_name, max_episode_steps,
                          resize_factor=resize_factor,
                          terminate_on_timeout=True,
                          thin=thin)

agent = UvfAgent(
    tf_env.time_step_spec(),
    tf_env.action_spec(),
    max_episode_steps=max_episode_steps,
    use_distributional_rl=True,
    ensemble_size=3)
# Out:
# /home/blbudima/miniconda3/envs/sgm/lib/python3.6/site-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# WARNING:tensorflow:From /home/blbudima/miniconda3/envs/sgm/lib/python3.6/site-packages/tf_agents/agents/ddpg/actor_network.py:101: The name tf.keras.initializers.RandomUniform is deprecated. Please use tf.compat.v1.keras.initializers.RandomUniform instead.

# %% [markdown]
# # Train the agent

# %%
from sgm.trainer import train_eval

train_eval(agent,
          tf_env,
          eval_tf_env,
          initial_collect_steps=1000,
          eval_interval=1000,
          num_eval_episodes=10,
          num_iterations=30000,
          save_model_dir=model_dir,
          experiment_name=f"{env_name}_coordinate_{max_episode_steps}steps")
# Out:
# INFO:tensorflow:random_seed = 0
# WARNING:tensorflow:From /home/blbudima/miniconda3/envs/sgm/lib/python3.6/site-packages/tensorflow_core/python/ops/resource_variable_ops.py:1781: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From /home/blbudima/miniconda3/envs/sgm/lib/python3.6/site-packages/tf_agents/replay_buffers/tf_uniform_replay_buffer.py:545: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# INFO:tensorflow:Saving checkpoints to directory /home/blbudima/sgm/notebooks/../agents/thinned_spiral9x9/Spiral9x9_coordinate_30steps-May-13-2021-11-32-25-AM/ckpt
# INFO:tensorflow:Creating tensorboard summary writer with directory /home/blbudima/sgm/notebooks/../agents/thinned_spiral9x9/Spiral9x9_coordinate_30steps-May-13-2021-11-32-25-AM
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#   3%|▎         | 998/30000 [00:19<08:29, 56.93it/s]
# Saved checkpoint for step 1000: /home/blbudima/sgm/notebooks/../agents/thinned_spiral9x9/Spiral9x9_coordinate_30steps-May-13-2021-11-32-25-AM/ckpt/ckpt-1
# INFO:tensorflow:step = 1000, loss = 2.897648
# INFO:tensorflow:56.599 steps/sec
# INFO:tensorflow:step = 1000
# INFO:tensorflow:	 set goal dist = 2
# INFO:tensorflow:		 AverageReturn (eval distance=2.000000) -24.40
# INFO:tensorflow:		 predicted_dist = 20.6 (0.3)
# INFO:tensorflow:	 set goal dist = 5
# INFO:tensorflow:		 AverageReturn (eval distance=5.000000) -30.00
# INFO:tensorflow:		 predicted_dist = 21.2 (0.3)
# INFO:tensorflow:	 set goal dist = 10
# INFO:tensorflow:		 AverageReturn (eval distance=10.000000) -26.60
# INFO:tensorflow:		 predicted_dist = 21.6 (0.5)
# INFO:tensorflow:	 eval_time = 4.80
#   7%|▋         | 1997/30000 [00:42<08:05, 57.62it/s]
# Saved checkpoint for step 2000: /home/blbudima/sgm/notebooks/../agents/thinned_spiral9x9/Spiral9x9_coordinate_30steps-May-13-2021-11-32-25-AM/ckpt/ckpt-2
# INFO:tensorflow:step = 2000, loss = 1.816824
# INFO:tensorflow:65.521 steps/sec
# INFO:tensorflow:step = 2000
# INFO:tensorflow:	 set goal dist = 2
# INFO:tensorflow:		 AverageReturn (eval distance=2.000000)
: /home/blbudima/sgm/notebooks/../agents/thinned_spiral9x9/Spiral9x9_coordinate_30steps-May-13-2021-11-32-25-AM/ckpt/ckpt-28
# INFO:tensorflow:step = 28000, loss = 3.125958
# INFO:tensorflow:65.643 steps/sec
# INFO:tensorflow:step = 28000
# INFO:tensorflow:	 set goal dist = 2
# INFO:tensorflow:		 AverageReturn (eval distance=2.000000) -3.60
# INFO:tensorflow:		 predicted_dist = 4.4 (1.8)
# INFO:tensorflow:	 set goal dist = 5
# INFO:tensorflow:		 AverageReturn (eval distance=5.000000) -8.10
# INFO:tensorflow:		 predicted_dist = 10.2 (2.2)
# INFO:tensorflow:	 set goal dist = 10
# INFO:tensorflow:		 AverageReturn (eval distance=10.000000) -18.30
# INFO:tensorflow:		 predicted_dist = 16.3 (2.7)
# INFO:tensorflow:	 eval_time = 2.39
#  97%|█████████▋| 28999/30000 [10:12<00:23, 42.71it/s]
# Saved checkpoint for step 29000: /home/blbudima/sgm/notebooks/../agents/thinned_spiral9x9/Spiral9x9_coordinate_30steps-May-13-2021-11-32-25-AM/ckpt/ckpt-29
# INFO:tensorflow:step = 29000, loss = 2.875728
# INFO:tensorflow:65.810 steps/sec
# INFO:tensorflow:step = 29000
# INFO:tensorflow:	 set goal dist = 2
# INFO:tensorflow:		 AverageReturn (eval distance=2.000000) -3.70
# INFO:tensorflow:		 predicted_dist = 5.6 (1.6)
# INFO:tensorflow:	 set goal dist = 5
# INFO:tensorflow:		 AverageReturn (eval distance=5.000000) -8.50
# INFO:tensorflow:		 predicted_dist = 9.3 (2.0)
# INFO:tensorflow:	 set goal dist = 10
# INFO:tensorflow:		 AverageReturn (eval distance=10.000000) -16.50
# INFO:tensorflow:		 predicted_dist = 14.9 (1.8)
# INFO:tensorflow:	 eval_time = 2.30
# 100%|█████████▉| 29998/30000 [10:32<00:00, 58.55it/s]
# Saved checkpoint for step 30000: /home/blbudima/sgm/notebooks/../agents/thinned_spiral9x9/Spiral9x9_coordinate_30steps-May-13-2021-11-32-25-AM/ckpt/ckpt-30
# INFO:tensorflow:step = 30000, loss = 3.023502
# INFO:tensorflow:65.907 steps/sec
# INFO:tensorflow:step = 30000
# INFO:tensorflow:	 set goal dist = 2
# INFO:tensorflow:		 AverageReturn (eval distance=2.000000) -4.00
# INFO:tensorflow:		 predicted_dist = 5.7 (1.4)
# INFO:tensorflow:	 set goal dist = 5
# INFO:tensorflow:		 AverageReturn (eval distance=5.000000) -8.50
# INFO:tensorflow:		 predicted_dist = 10.0 (1.2)
# INFO:tensorflow:	 set goal dist = 10
# INFO:tensorflow:		 AverageReturn (eval distance=10.000000) -17.80
# INFO:tensorflow:		 predicted_dist = 15.0 (1.5)
# INFO:tensorflow:	 eval_time = 2.34
# 100%|██████████| 30000/30000 [10:34<00:00, 47.25it/s]
# LossInfo(loss=<tf.Tensor: id=1149426, shape=(), dtype=float32, numpy=3.0235019>, extra=(<tf.Tensor: id=1149427, shape=(), dtype=float32, numpy=0.30313897>, <tf.Tensor: id=1149428, shape=(), dtype=float32, numpy=2.720363>))

# %% [markdown]
# # Load trained model into agent

# %%
filename = "Spiral9x9_coordinate_30steps-May-13-2021-11-32-25-AM/ckpt/"
checkpoint_file = os.path.join(model_dir, filename)

ckpt = tf.train.Checkpoint(step=tf.Variable(1), net=agent)
manager = tf.train.CheckpointManager(ckpt, checkpoint_file, max_to_keep=3)
ckpt.restore(manager.latest_checkpoint)

# %% [markdown]
# # Fill replay buffer with random prefectly explored data

# %%
from sgm.envs import *

#@title Fill the replay buffer with random data  {vertical-output: true, run: "auto" }
replay_buffer_size = 2000 #@param {min:100, max: 1000, step: 100, type:"slider"}

eval_tf_env.pyenv.envs[0].gym.set_sample_goal_args(
    prob_constraint=0.0,
    min_dist=0,
    max_dist=10)
rb_vec = []
for it in range(replay_buffer_size):
    ts = eval_tf_env.reset()
    rb_vec.append(ts.observation['observation'].numpy()[0])
rb_vec = np.array(rb_vec)

# %%
plt.figure(figsize=(6, 6))
plt.scatter(*rb_vec.T)
plot_walls(eval_tf_env.pyenv.envs[0].env.walls)
plt.show()

# %% [markdown]
# # Calculate qvalue distances

# %%
pdist = agent._get_pairwise_dist(rb_vec, aggregate=None).numpy()

# %%
plt.figure(figsize=(6, 3))
plt.hist(pdist.flatten(), bins=range(20))
plt.xlabel('predicted distance')
plt.ylabel('number of (s, g) pairs')
plt.show()

# %% [markdown]
# # Tune edge cutoff

# %%
from sgm.planner import SGMSearchPolicy
search_policy_type = "SGM"
agent.initialize_search(rb_vec, max_search_steps=30) # needed to set agent attributes that SGMSearchPolicy constructor queries
search_policy = SGMSearchPolicy(agent, pdist, rb_vec, rb_vec, cache_pdist = True)
agent.initialize_search(search_policy.rb_vec, max_search_steps=30)

from sgm.utils.visualization import *
plot_graph(search_policy._g.copy(), search_policy.rb_vec, eval_tf_env)
# Out:
# Plotting 226 nodes and 1743 edges

# %%
search_policy.keep_k_nearest(5)
plot_graph(search_policy._g.copy(), search_policy.rb_vec, eval_tf_env)
# Out:
# Plotting 226 nodes and 1098 edges

# %%
search_policy.keep_k_nearest(4)
plot_graph(search_policy._g.copy(), search_policy.rb_vec, eval_tf_env)
# Out:
# Plotting 226 nodes and 890 edges

# %%
search_policy.keep_k_nearest(3)
plot_graph(search_policy._g.copy(), search_policy.rb_vec, eval_tf_env)
# Out:
# Plotting 226 nodes and 672 edges

# %%
search_policy.keep_k_nearest(2)
plot_graph(search_policy._g.copy(), search_policy.rb_vec, eval_tf_env)
# Out:
# Plotting 226 nodes and 450 edges

# %%
search_policy.keep_k_nearest(1)
plot_graph(search_policy._g.copy(), search_policy.rb_vec, eval_tf_env)
# Out:
# Plotting 226 nodes and 226 edges

# %% [markdown]
# # Calculate Euclidean distances

# %%
from scipy.spatial import distance
euclidean_dists = distance.pdist(rb_vec)

plt.figure(figsize=(6, 3))
plt.hist(euclidean_dists.flatten())
plt.xlabel('Euclidean distance')
plt.ylabel('number of pairwise distances')
plt.show()

# %% [markdown]
# # Initialize SGM search policy

# %%
from sgm.planner import SGMSearchPolicy
search_policy_type = "SGM"
agent.initialize_search(rb_vec, max_search_steps=30) # needed to set agent attributes that SGMSearchPolicy constructor queries
search_policy = SGMSearchPolicy(agent, pdist, rb_vec, rb_vec, cache_pdist = True)
agent.initialize_search(search_policy.rb_vec, max_search_steps=30)

# %% [markdown]
# # Cleanup and evaluate SGM

# %%
from sgm.evaluation import cleanup_and_eval

logdir = os.path.join(os.getcwd(), os.pardir, "logs")
eval_difficulty = 0.95
k_nearest = 5
eval_trials = 20
total_cleanup_steps = 50000
eval_period = 5000

logfolder = cleanup_and_eval(search_policy,
                             search_policy_type,
                             desc_name,
                             eval_tf_env,
                             logdir,
                             eval_difficulty=eval_difficulty,
                             k_nearest=k_nearest,
                             eval_trials=eval_trials,
                             total_cleanup_steps=total_cleanup_steps,
                             eval_period=eval_period)
# Out:
# SGM has initial success rate 0.00
# Evaluated initial SGM success rate in 528.73 seconds
# After filtering and 0 cleanup steps, SGM has success rate 0.00
# Took 5000 cleanup steps and evaluated SGM success rate in 867.98 seconds
# After filtering and 5000 cleanup steps, SGM has success rate 0.00
# Took 5000 cleanup steps and evaluated SGM success rate in 840.32 seconds
# After filtering and 10000 cleanup steps, SGM has success rate 0.00
# Took 5000 cleanup steps and evaluated SGM success rate in 845.79 seconds
# After filtering and 15000 cleanup steps, SGM has success rate 0.00
# Took 5000 cleanup steps and evaluated SGM success rate in 841.07 seconds
# After filtering and 20000 cleanup steps, SGM has success rate 0.00
# Took 5000 cleanup steps and evaluated SGM success rate in 835.36 seconds
# After filtering and 25000 cleanup steps, SGM has success rate 0.00
# Took 5000 cleanup steps and evaluated SGM success rate in 916.48 seconds
# After filtering and 30000 cleanup steps, SGM has success rate 0.00
# Took 5000 cleanup steps and evaluated SGM success rate in 913.93 seconds
# After filtering and 35000 cleanup steps, SGM has success rate 0.00
# Took 5000 cleanup steps and evaluated SGM success rate in 895.19 seconds
# After filtering and 40000 cleanup steps, SGM has success rate 0.00
# Took 5000 cleanup steps and evaluated SGM success rate in 863.89 seconds
# After filtering and 45000 cleanup steps, SGM has success rate 0.00
# Took 5000 cleanup steps and evaluated SGM success rate in 881.42 seconds
# After filtering and 50000 cleanup steps, SGM has success rate 0.00

# %% [markdown]
# # Load cleanup graphs

# %%
from sgm.utils.visualization import *

search_policy.load(os.path.join(logfolder, search_policy_type.lower().replace(" ", "_") + "_initial"))
initial_graph = search_policy._g.copy()

search_policy.load(os.path.join(logfolder, search_policy_type.lower().replace(" ", "_") + "_filtered_0_cleanup_steps/"))
filtered_graph = search_policy._g.copy()

search_policy.load(os.path.join(logfolder, search_policy_type.lower().replace(" ", "_") + "_filtered_{}_cleanup_steps/".format(total_cleanup_steps)))
cleaned_graph = search_policy._g.copy()

pruned_graph = nx.difference(filtered_graph, cleaned_graph)

# %% [markdown]
# # Visualize cleanup graphs

# %%
plot_points(search_policy.rb_vec, eval_tf_env)

# %%
plot_graph(initial_graph, search_policy.rb_vec, eval_tf_env)
# Out:
# Plotting 226 nodes and 1743 edges

# %%
plot_graph(filtered_graph, search_policy.rb_vec, eval_tf_env)
# Out:
# Plotting 226 nodes and 1098 edges

# %%
plot_graph(cleaned_graph, search_policy.rb_vec, eval_tf_env)
# Out:
# Plotting 226 nodes and 998 edges

# %%
plot_graph(pruned_graph, search_policy.rb_vec, eval_tf_env)
# Out:
# Plotting 226 nodes and 100 edges
