# %% [markdown]
# # Import dependencies

# %%
# Reload modules whenever underlying code changes
# %load_ext autoreload
# %autoreload 2

# %%
# pdb will automatically run on exceptions
#%pdb on # currently not working due to https://github.com/ipython/ipykernel/issues/422

# %%
# import os

# # Only occupy one GPU, as in https://stackoverflow.com/questions/37893755/tensorflow-set-cuda-visible-devices-within-jupyter
# os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"   # see issue #152
# os.environ["CUDA_VISIBLE_DEVICES"]="0"

# # Only allocate GPU memory as needed
# os.environ["TF_FORCE_GPU_ALLOW_GROWTH"]="true"

# # Suppress tf warning messages
# os.environ["TF_CPP_MIN_LOG_LEVEL"]="3"

# %%
# %matplotlib inline
from sgm.dependencies import *

# %% [markdown]
# # Initialize untrained agent

# %%
# config = tf.ConfigProto()
# config.gpu_options.allow_growth = True
# tf.enable_eager_execution(config=config)

# %%
# tf.debugging.set_log_device_placement(True)
tf.test.is_gpu_available()
# Out:
# True

# %%
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 16680462387320582466
# , name: "/device:XLA_CPU:0"
# device_type: "XLA_CPU"
# memory_limit: 17179869184
# locality {
# }
# incarnation: 14941087204764697836
# physical_device_desc: "device: XLA_CPU device"
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 10990990132
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 333629116909855138
# physical_device_desc: "device: 0, name: GeForce GTX 1080 Ti, pci bus id: 0000:3e:00.0, compute capability: 6.1"
# , name: "/device:XLA_GPU:0"
# device_type: "XLA_GPU"
# memory_limit: 17179869184
# locality {
# }
# incarnation: 2405050866225294444
# physical_device_desc: "device: XLA_GPU device"
# ]

# %%
tf.reset_default_graph()

# %%
from sgm.envs import env_load_fn
from sgm.agent import UvfAgent

# If you change the environment parameters below, make sure to run
# tf.reset_default_graph() in the cell above before training.
max_episode_steps = 20
env_name = 'Maze11x11'  # Choose one of the environments shown above. 
resize_factor = 5  # Inflate the environment to increase the difficulty.
thin = True # If True, resize by expanding open space, not walls, to make walls thin
desc_name = "thinned_" + env_name.lower() if thin else env_name.lower()

base_dir = os.path.join(os.getcwd(), os.pardir, "agents")
model_dir = os.path.join(base_dir, desc_name)

tf_env = env_load_fn(env_name, max_episode_steps,
                     resize_factor=resize_factor,
                     terminate_on_timeout=False,
                     thin=thin)
eval_tf_env = env_load_fn(env_name, max_episode_steps,
                          resize_factor=resize_factor,
                          terminate_on_timeout=True,
                          thin=thin)

agent = UvfAgent(
    tf_env.time_step_spec(),
    tf_env.action_spec(),
    max_episode_steps=max_episode_steps,
    use_distributional_rl=True,
    ensemble_size=3)
# Out:
# /home/blbudima/miniconda3/envs/sgm/lib/python3.6/site-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# WARNING:tensorflow:From /home/blbudima/miniconda3/envs/sgm/lib/python3.6/site-packages/tf_agents/agents/ddpg/actor_network.py:101: The name tf.keras.initializers.RandomUniform is deprecated. Please use tf.compat.v1.keras.initializers.RandomUniform instead.

# %% [markdown]
# # Train the agent

# %%
# from sgm.trainer import train_eval

# train_eval(agent,
#           tf_env,
#           eval_tf_env,
#           initial_collect_steps=1000,
#           eval_interval=1000,
#           num_eval_episodes=10,
#           num_iterations=30000,
#           save_model_dir=model_dir,
#           experiment_name=f"{env_name}_coordinate_{max_episode_steps}steps")
# Out:
# INFO:tensorflow:random_seed = 0
# WARNING:tensorflow:From /home/blbudima/miniconda3/envs/sgm/lib/python3.6/site-packages/tensorflow_core/python/ops/resource_variable_ops.py:1781: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From /home/blbudima/miniconda3/envs/sgm/lib/python3.6/site-packages/tf_agents/replay_buffers/tf_uniform_replay_buffer.py:545: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# INFO:tensorflow:Saving checkpoints to directory /home/blbudima/sgm/notebooks/../agents/thinned_maze11x11/Maze11x11_coordinate_20steps-May-10-2021-04-58-04-PM/ckpt
# INFO:tensorflow:Creating tensorboard summary writer with directory /home/blbudima/sgm/notebooks/../agents/thinned_maze11x11/Maze11x11_coordinate_20steps-May-10-2021-04-58-04-PM
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#   3%|▎         | 996/30000 [00:20<08:24, 57.45it/s]
# Saved checkpoint for step 1000: /home/blbudima/sgm/notebooks/../agents/thinned_maze11x11/Maze11x11_coordinate_20steps-May-10-2021-04-58-04-PM/ckpt/ckpt-1
# INFO:tensorflow:step = 1000, loss = 2.184391
# INFO:tensorflow:52.591 steps/sec
# INFO:tensorflow:step = 1000
# INFO:tensorflow:	 set goal dist = 2
# INFO:tensorflow:		 AverageReturn (eval distance=2.000000) -16.40
# INFO:tensorflow:		 predicted_dist = 15.4 (0.2)
# INFO:tensorflow:	 set goal dist = 5
# INFO:tensorflow:		 AverageReturn (eval distance=5.000000) -19.90
# INFO:tensorflow:		 predicted_dist = 15.6 (0.3)
# INFO:tensorflow:	 set goal dist = 10
# INFO:tensorflow:		 AverageReturn (eval distance=10.000000) -20.00
# INFO:tensorflow:		 predicted_dist = 15.9 (0.4)
# INFO:tensorflow:	 eval_time = 4.69
#   7%|▋         | 1996/30000 [00:44<08:08, 57.34it/s]
# Saved checkpoint for step 2000: /home/blbudima/sgm/notebooks/../agents/thinned_maze11x11/Maze11x11_coordinate_20steps-May-10-2021-04-58-04-PM/ckpt/ckpt-2
# INFO:tensorflow:step = 2000, loss = 1.289950
# INFO:tensorflow:63.465 steps/sec
# INFO:tensorflow:step = 2000
# INFO:tensorflow:	 set goal dist = 2
# INFO:tensorflow:		 AverageReturn (eval distance=2.000000)

# INFO:tensorflow:	 set goal dist = 2
# INFO:tensorflow:		 AverageReturn (eval distance=2.000000) -7.10
# INFO:tensorflow:		 predicted_dist = 7.3 (2.1)
# INFO:tensorflow:	 set goal dist = 5
# INFO:tensorflow:		 AverageReturn (eval distance=5.000000) -7.10
# INFO:tensorflow:		 predicted_dist = 10.9 (0.7)
# INFO:tensorflow:	 set goal dist = 10
# INFO:tensorflow:		 AverageReturn (eval distance=10.000000) -18.60
# INFO:tensorflow:		 predicted_dist = 13.0 (0.7)
# INFO:tensorflow:	 eval_time = 2.61
#  77%|███████▋  | 22995/30000 [08:27<02:12, 52.77it/s]
# Saved checkpoint for step 23000: /home/blbudima/sgm/notebooks/../agents/thinned_maze11x11/Maze11x11_coordinate_20steps-May-10-2021-04-58-04-PM/ckpt/ckpt-23
# INFO:tensorflow:step = 23000, loss = 2.679764
# INFO:tensorflow:60.783 steps/sec
# INFO:tensorflow:step = 23000
# INFO:tensorflow:	 set goal dist = 2
# INFO:tensorflow:		 AverageReturn (eval distance=2.000000) -3.20
# INFO:tensorflow:		 predicted_dist = 6.6 (1.2)
# INFO:tensorflow:	 set goal dist = 5
# INFO:tensorflow:		 AverageReturn (eval distance=5.000000) -8.20
# INFO:tensorflow:		 predicted_dist = 10.2 (0.9)
# INFO:tensorflow:	 set goal dist = 10
# INFO:tensorflow:		 AverageReturn (eval distance=10.000000) -18.30
# INFO:tensorflow:		 predicted_dist = 12.7 (1.4)
# INFO:tensorflow:	 eval_time = 2.51
#  80%|███████▉  | 23994/30000 [08:49<01:44, 57.63it/s]
# Saved checkpoint for step 24000: /home/blbudima/sgm/notebooks/../agents/thinned_maze11x11/Maze11x11_coordinate_20steps-May-10-2021-04-58-04-PM/ckpt/ckpt-24
# INFO:tensorflow:step = 24000, loss = 3.087215
# INFO:tensorflow:61.308 steps/sec
# INFO:tensorflow:step = 24000
# INFO:tensorflow:	 set goal dist = 2
# INFO:tensorflow:		 AverageReturn (eval distance=2.000000) -2.50
# INFO:tensorflow:		 predicted_dist = 7.0 (1.4)
# INFO:tensorflow:	 set goal dist = 5
# INFO:tensorflow:		 AverageReturn (eval distance=5.000000) -9.00
# INFO:tensorflow:		 predicted_dist = 9.6 (0.7)
# INFO:tensorflow:	 set goal dist = 10
# INFO:tensorflow:		 AverageReturn (eval distance=10.000000) -16.50
# INFO:tensorflow:		 predicted_dist = 12.0 (0.8)
# INFO:tensorflow:	 eval_time = 2.38
#  83%|████████▎ | 24994/30000 [09:10<01:26, 57.79it/s]
# Saved checkpoint for step 25000: /home/blbudima/sgm/notebooks/../agents/thinned_maze11x11/Maze11x11_coordinate_20steps-May-10-2021-04-58-04-PM/ckpt/ckpt-25
# INFO:tensorflow:step = 25000, loss = 2.798977
# INFO:tensorflow:62.588 steps/sec
# INFO:tensorflow:step = 25000
# INFO:tensorflow:	 set goal dist = 2
# INFO:tensorflow:		 AverageReturn (eval distance=2.000000) -3.00
# INFO:tensorflow:		 predicted_dist = 7.3 (0.8)
# INFO:tensorflow:	 set goal dist = 5
# INFO:tensorflow:		 AverageReturn (eval distance=5.000000) -10.00
# INFO:tensorflow:		 predicted_dist = 9.9 (0.6)
# INFO:tensorflow:	 set goal dist = 10
# INFO:tensorflow:		 AverageReturn (eval distance=10.000000) -17.00
# INFO:tensorflow:		 predicted_dist = 11.7 (0.5)
# INFO:tensorflow:	 eval_time = 2.51
#  87%|████████▋ | 25997/30000 [09:31<01:13, 54.34it/s]
# Saved checkpoint for step 26000: /home/blbudima/sgm/notebooks/../agents/thinned_maze11x11/Maze11x11_coordinate_20steps-May-10-2021-04-58-04-PM/ckpt/ckpt-26
# INFO:tensorflow:step = 26000, loss = 2.816948
# INFO:tensorflow:57.759 steps/sec
# INFO:tensorflow:step = 26000
# INFO:tensorflow:	 set goal dist = 2
# INFO:tensorflow:		 AverageReturn (eval distance=2.000000) -5.10
# INFO:tensorflow:		 predicted_dist = 6.2 (1.7)
# INFO:tensorflow:	 set goal dist = 5
# INFO:tensorflow:		 AverageReturn (eval distance=5.000000) -9.30
# INFO:tensorflow:		 predicted_dist = 9.9 (1.3)
# INFO:tensorflow:	 set goal dist = 10
# INFO:tensorflow:		 AverageReturn (eval distance=10.000000) -17.10
# INFO:tensorflow:		 predicted_dist = 12.7 (1.0)
# INFO:tensorflow:	 eval_time = 2.60
#  90%|████████▉ | 26997/30000 [09:53<00:54, 55.17it/s]
# Saved checkpoint for step 27000: /home/blbudima/sgm/notebooks/../agents/thinned_maze11x11/Maze11x11_coordinate_20steps-May-10-2021-04-58-04-PM/ckpt/ckpt-27
# INFO:tensorflow:step = 27000, loss = 3.258410
# INFO:tensorflow:60.946 steps/sec
# INFO:tensorflow:step = 27000
# INFO:tensorflow:	 set goal dist = 2
# INFO:tensorflow:		 AverageReturn (eval distance=2.000000) -4.70
# INFO:tensorflow:		 predicted_dist = 6.6 (0.5)
# INFO:tensorflow:	 set goal dist = 5
# INFO:tensorflow:		 AverageReturn (eval distance=5.000000) -7.30
# INFO:tensorflow:		 predicted_dist = 10.4 (1.2)
# INFO:tensorflow:	 set goal dist = 10
# INFO:tensorflow:		 AverageReturn (eval distance=10.000000) -15.00
# INFO:tensorflow:		 predicted_dist = 12.6 (0.7)
# INFO:tensorflow:	 eval_time = 2.48
#  93%|█████████▎| 27998/30000 [10:15<00:37, 53.55it/s]
# Saved checkpoint for step 28000: /home/blbudima/sgm/notebooks/../agents/thinned_maze11x11/Maze11x11_coordinate_20steps-May-10-2021-04-58-04-PM/ckpt/ckpt-28
# INFO:tensorflow:step = 28000, loss = 2.950479
# INFO:tensorflow:59.222 steps/sec
# INFO:tensorflow:step = 28000
# INFO:tensorflow:	 set goal dist = 2
# INFO:tensorflow:		 AverageReturn (eval distance=2.000000) -3.90
# INFO:tensorflow:		 predicted_dist = 7.3 (1.6)
# INFO:tensorflow:	 set goal dist = 5
# INFO:tensorflow:		 AverageReturn (eval distance=5.000000) -8.80
# INFO:tensorflow:		 predicted_dist = 9.5 (1.1)
# INFO:tensorflow:	 set goal dist = 10
# INFO:tensorflow:		 AverageReturn (eval distance=10.000000) -17.30
# INFO:tensorflow:		 predicted_dist = 12.2 (0.9)
# INFO:tensorflow:	 eval_time = 2.50
#  97%|█████████▋| 28999/30000 [10:37<00:30, 33.06it/s]
# Saved checkpoint for step 29000: /home/blbudima/sgm/notebooks/../agents/thinned_maze11x11/Maze11x11_coordinate_20steps-May-10-2021-04-58-04-PM/ckpt/ckpt-29
# INFO:tensorflow:step = 29000, loss = 2.957778
# INFO:tensorflow:62.038 steps/sec
# INFO:tensorflow:step = 29000
# INFO:tensorflow:	 set goal dist = 2
# INFO:tensorflow:		 AverageReturn (eval distance=2.000000) -3.30
# INFO:tensorflow:		 predicted_dist = 5.9 (1.7)
# INFO:tensorflow:	 set goal dist = 5
# INFO:tensorflow:		 AverageReturn (eval distance=5.000000) -10.00
# INFO:tensorflow:		 predicted_dist = 9.8 (0.8)
# INFO:tensorflow:	 set goal dist = 10
# INFO:tensorflow:		 AverageReturn (eval distance=10.000000) -17.30
# INFO:tensorflow:		 predicted_dist = 12.9 (1.0)
# INFO:tensorflow:	 eval_time = 2.44
# 100%|█████████▉| 29995/30000 [10:57<00:00, 56.37it/s]
# Saved checkpoint for step 30000: /home/blbudima/sgm/notebooks/../agents/thinned_maze11x11/Maze11x11_coordinate_20steps-May-10-2021-04-58-04-PM/ckpt/ckpt-30
# INFO:tensorflow:step = 30000, loss = 2.879403
# INFO:tensorflow:59.479 steps/sec
# INFO:tensorflow:step = 30000
# INFO:tensorflow:	 set goal dist = 2
# INFO:tensorflow:		 AverageReturn (eval distance=2.000000) -3.60
# INFO:tensorflow:		 predicted_dist = 6.9 (1.7)
# INFO:tensorflow:	 set goal dist = 5
# INFO:tensorflow:		 AverageReturn (eval distance=5.000000) -8.00
# INFO:tensorflow:		 predicted_dist = 8.9 (0.8)
# INFO:tensorflow:	 set goal dist = 10
# INFO:tensorflow:		 AverageReturn (eval distance=10.000000) -18.10
# INFO:tensorflow:		 predicted_dist = 11.6 (0.8)
# INFO:tensorflow:	 eval_time = 2.57
# 100%|██████████| 30000/30000 [11:01<00:00, 45.36it/s]
# LossInfo(loss=<tf.Tensor: id=1149426, shape=(), dtype=float32, numpy=2.8794026>, extra=(<tf.Tensor: id=1149427, shape=(), dtype=float32, numpy=0.51133466>, <tf.Tensor: id=1149428, shape=(), dtype=float32, numpy=2.368068>))

# %% [markdown]
# # Load trained model into agent

# %%
filename = "Maze11x11_coordinate_20steps-May-10-2021-04-58-04-PM/ckpt/"
checkpoint_file = os.path.join(model_dir, filename)

ckpt = tf.train.Checkpoint(step=tf.Variable(1), net=agent)
manager = tf.train.CheckpointManager(ckpt, checkpoint_file, max_to_keep=3)
ckpt.restore(manager.latest_checkpoint)

# %% [markdown]
# # Fill replay buffer with random prefectly explored data

# %%
from sgm.envs import *

#@title Fill the replay buffer with random data  {vertical-output: true, run: "auto" }
replay_buffer_size = 2000 #@param {min:100, max: 1000, step: 100, type:"slider"}

eval_tf_env.pyenv.envs[0].gym.set_sample_goal_args(
    prob_constraint=0.0,
    min_dist=0,
    max_dist=np.inf)
rb_vec = []
for it in range(replay_buffer_size):
    ts = eval_tf_env.reset()
    rb_vec.append(ts.observation['observation'].numpy()[0])
rb_vec = np.array(rb_vec)

# %%
plt.figure(figsize=(6, 6))
plt.scatter(*rb_vec.T)
plot_walls(eval_tf_env.pyenv.envs[0].env.walls)
plt.show()

# %% [markdown]
# # Calculate qvalue distances

# %%
pdist = agent._get_pairwise_dist(rb_vec, aggregate=None).numpy()

# %%
plt.figure(figsize=(6, 3))
plt.hist(pdist.flatten(), bins=range(20))
plt.xlabel('predicted distance')
plt.ylabel('number of (s, g) pairs')
plt.show()

# %% [markdown]
# # Tune edge cutoff

# %%
from sgm.planner import SGMSearchPolicy
search_policy_type = "SGM"
agent.initialize_search(rb_vec, max_search_steps=10) # needed to set agent attributes that SGMSearchPolicy constructor queries
search_policy = SGMSearchPolicy(agent, pdist, rb_vec, rb_vec, cache_pdist = True)
agent.initialize_search(search_policy.rb_vec, max_search_steps=10)

from sgm.utils.visualization import *
plot_graph(search_policy._g.copy(), search_policy.rb_vec, eval_tf_env)
# Out:
# Plotting 216 nodes and 1536 edges

# %%
search_policy.keep_k_nearest(5)
plot_graph(search_policy._g.copy(), search_policy.rb_vec, eval_tf_env)
# Out:
# Plotting 216 nodes and 1035 edges

# %%
search_policy.keep_k_nearest(4)
plot_graph(search_policy._g.copy(), search_policy.rb_vec, eval_tf_env)
# Out:
# Plotting 216 nodes and 846 edges

# %%
search_policy.keep_k_nearest(3)
plot_graph(search_policy._g.copy(), search_policy.rb_vec, eval_tf_env)
# Out:
# Plotting 216 nodes and 642 edges

# %%
search_policy.keep_k_nearest(2)
plot_graph(search_policy._g.copy(), search_policy.rb_vec, eval_tf_env)
# Out:
# Plotting 216 nodes and 432 edges

# %%
search_policy.keep_k_nearest(1)
plot_graph(search_policy._g.copy(), search_policy.rb_vec, eval_tf_env)
# Out:
# Plotting 216 nodes and 216 edges

# %% [markdown]
# # Calculate Euclidean distances

# %%
from scipy.spatial import distance
euclidean_dists = distance.pdist(rb_vec)

plt.figure(figsize=(6, 3))
plt.hist(euclidean_dists.flatten())
plt.xlabel('Euclidean distance')
plt.ylabel('number of pairwise distances')
plt.show()

# %% [markdown]
# # Initialize SGM search policy

# %%
from sgm.planner import SGMSearchPolicy
search_policy_type = "SGM"
agent.initialize_search(rb_vec, max_search_steps=10) # needed to set agent attributes that SGMSearchPolicy constructor queries
search_policy = SGMSearchPolicy(agent, pdist, rb_vec, rb_vec, cache_pdist = True)
agent.initialize_search(search_policy.rb_vec, max_search_steps=10)

# %% [markdown]
# # Cleanup and evaluate SGM

# %%
from sgm.evaluation import cleanup_and_eval

logdir = os.path.join(os.getcwd(), os.pardir, "logs")
eval_difficulty = 0.95
k_nearest = 4
eval_trials = 20
total_cleanup_steps = 50000
eval_period = 5000

logfolder = cleanup_and_eval(search_policy,
                             search_policy_type,
                             desc_name,
                             eval_tf_env,
                             logdir,
                             eval_difficulty=eval_difficulty,
                             k_nearest=k_nearest,
                             eval_trials=eval_trials,
                             total_cleanup_steps=total_cleanup_steps,
                             eval_period=eval_period)
# Out:
# SGM has initial success rate 0.00
# Evaluated initial SGM success rate in 611.96 seconds
# After filtering and 0 cleanup steps, SGM has success rate 0.00
# Took 5000 cleanup steps and evaluated SGM success rate in 1276.01 seconds
# After filtering and 5000 cleanup steps, SGM has success rate 0.00
# Took 5000 cleanup steps and evaluated SGM success rate in 1248.27 seconds
# After filtering and 10000 cleanup steps, SGM has success rate 0.00
# Took 5000 cleanup steps and evaluated SGM success rate in 1293.97 seconds
# After filtering and 15000 cleanup steps, SGM has success rate 0.00
# Took 5000 cleanup steps and evaluated SGM success rate in 1288.50 seconds
# After filtering and 20000 cleanup steps, SGM has success rate 0.00
# Took 5000 cleanup steps and evaluated SGM success rate in 1308.39 seconds
# After filtering and 25000 cleanup steps, SGM has success rate 0.00
# Took 5000 cleanup steps and evaluated SGM success rate in 1326.48 seconds
# After filtering and 30000 cleanup steps, SGM has success rate 0.00
# Took 5000 cleanup steps and evaluated SGM success rate in 1296.82 seconds
# After filtering and 35000 cleanup steps, SGM has success rate 0.00
# Took 5000 cleanup steps and evaluated SGM success rate in 1298.17 seconds
# After filtering and 40000 cleanup steps, SGM has success rate 0.00
# Took 5000 cleanup steps and evaluated SGM success rate in 1377.57 seconds
# After filtering and 45000 cleanup steps, SGM has success rate 0.00
# Took 5000 cleanup steps and evaluated SGM success rate in 1353.42 seconds
# After filtering and 50000 cleanup steps, SGM has success rate 0.00

# %% [markdown]
# # Load cleanup graphs

# %%
from sgm.utils.visualization import *

search_policy.load(os.path.join(logfolder, search_policy_type.lower().replace(" ", "_") + "_initial"))
initial_graph = search_policy._g.copy()

search_policy.load(os.path.join(logfolder, search_policy_type.lower().replace(" ", "_") + "_filtered_0_cleanup_steps/"))
filtered_graph = search_policy._g.copy()

search_policy.load(os.path.join(logfolder, search_policy_type.lower().replace(" ", "_") + "_filtered_{}_cleanup_steps/".format(total_cleanup_steps)))
cleaned_graph = search_policy._g.copy()

pruned_graph = nx.difference(filtered_graph, cleaned_graph)

# %% [markdown]
# # Visualize cleanup graphs

# %%
plot_points(search_policy.rb_vec, eval_tf_env)

# %%
plot_graph(initial_graph, search_policy.rb_vec, eval_tf_env)
# Out:
# Plotting 216 nodes and 1536 edges

# %%
plot_graph(filtered_graph, search_policy.rb_vec, eval_tf_env)
# Out:
# Plotting 216 nodes and 846 edges

# %%
plot_graph(cleaned_graph, search_policy.rb_vec, eval_tf_env)
# Out:
# Plotting 216 nodes and 785 edges

# %%
plot_graph(pruned_graph, search_policy.rb_vec, eval_tf_env)
# Out:
# Plotting 216 nodes and 61 edges
